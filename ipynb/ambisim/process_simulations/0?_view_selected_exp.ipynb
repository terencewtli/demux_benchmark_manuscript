# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os

# %%
basedir = '/u/home/t/terencew/project-cluo/igvf/pilot/multiome/'

donors = list(np.loadtxt(f'{basedir}/txt/donors.txt', dtype=str))
samples = list(np.loadtxt(f'{basedir}/txt/samples.txt', dtype=str))
s = samples[0]

gex_methods = pd.Index(['demuxlet', 'freemuxlet',  'vireo', 'vireo_nogenos',
    'souporcell', 'souporcell_nogenos', 'scsplit', 'scsplit_nogenos', 'demuxalot'])
atac_methods = pd.Index(['demuxlet', 'freemuxlet',  'vireo', 'vireo_nogenos',
    'souporcell', 'souporcell_nogenos', 'scsplit', 'scsplit_nogenos', 'scavengers'])

free_methods = pd.Index(['freemuxlet', 'vireo_nogenos', 'souporcell',
                'souporcell_nogenos', 'scsplit', 'scsplit_nogenos', 'scavengers'])

doub_experiments = np.loadtxt(f'{basedir}/ambient/ambisim/cov_doub_test/txt/experiments.txt', dtype=str)
mux_experiments = np.loadtxt(f'{basedir}/ambient/ambisim/cov_mux_test/txt/experiments.txt', dtype=str)

# %%
projdir = f'{basedir}/ambient/ambisim/cov_mux_test/'
s = samples[0]
mod = 'gex'
method = 'freemuxlet'

exp = '16_20'

indir = f'{projdir}/{exp}/demux/merged/{mod}/{s}'
demux = pd.read_csv(f'{indir}/{method}.csv', sep='\t', header=0, index_col=0).sort_index()

# %%
demux['donor_id'].value_counts()
# Out:
# 0          8903
# doublet      88
# 1             5
# 2             2
# 3             1
# Name: donor_id, dtype: int64

# %%
demux
# Out:
#                     INT_ID  NUM.SNPS  NUM.READS DROPLET.TYPE BEST.GUESS  \
# BARCODE
# AAACAGCCAAACAACA-1    5456      1854       1904          SNG        0,0
# AAACAGCCAAACATAG-1    6838      2308       2429          SNG        0,0
# AAACAGCCAAACCCTA-1    4778      1551       1641          SNG        0,0
# AAACAGCCAAACCTAT-1    6958       405        413          SNG        0,0
# AAACAGCCAAACCTTG-1    3679      3934       4235          SNG        0,0
# ...                    ...       ...        ...          ...        ...
# AACAAGCCACTGACTA-1    5134      1152       1200          SNG        0,0
# AACAAGCCACTGGCCA-1    1386      1443       1496          SNG        0,0
# AACAAGCCACTGGCTG-1     492      3352       3590          SNG        0,0
# AACAAGCCACTTAACG-1    7401      1110       1154          SNG        0,0
# AACAAGCCACTTACAG-1    1691      2559       2722          SNG        0,0
#
#                     BEST.LLK NEXT.GUESS  NEXT.LLK  DIFF.LLK.BEST.NEXT  \
# BARCODE
# AAACAGCCAAACAACA-1  -3610.15        1,0  -3658.18               48.02
# AAACAGCCAAACATAG-1  -4413.20        4,0  -4497.91               84.71
# AAACAGCCAAACCCTA-1  -3008.70        1,0  -3040.60               31.90
# AAACAGCCAAACCTAT-1   -797.25        1,0   -804.85                7.59
# AAACAGCCAAACCTTG-1  -7606.74        2,0  -7759.56              152.82
# ...                      ...        ...       ...                 ...
# AACAAGCCACTGACTA-1  -2221.37        3,0  -2246.44               25.06
# AACAAGCCACTGGCCA-1  -2899.72        3,0  -2934.66               34.93
# AACAAGCCACTGGCTG-1  -6537.78        1,0  -6605.68               67.89
# AACAAGCCACTTAACG-1  -2140.33        3,0  -2185.15               44.81
# AACAAGCCACTTACAG-1  -4947.31        2,0  -5024.36               77.05
#
#                     BEST.POSTERIOR  SNG.POSTERIOR donor_id  SNG.BEST.LLK  \
# BARCODE
# AAACAGCCAAACAACA-1         0.00000            1.0        0      -3610.15
# AAACAGCCAAACATAG-1         0.00000            1.0        0      -4413.20
# AAACAGCCAAACCCTA-1         0.00000            1.0        0      -3008.70
# AAACAGCCAAACCTAT-1        -0.00007            1.0        0       -797.25
# AAACAGCCAAACCTTG-1         0.00000            1.0        0      -7606.74
# ...                            ...            ...      ...           ...
# AACAAGCCACTGACTA-1        -0.00000            1.0        0      -2221.37
# AACAAGCCACTGGCCA-1         0.00000            1.0        0      -2899.72
# AACAAGCCACTGGCTG-1         0.00000            1.0        0      -6537.78
# AACAAGCCACTTAACG-1         0.00000            1.0        0      -2140.33
# AACAAGCCACTTACAG-1         0.00000            1.0        0      -4947.31
#
#                     SNG.NEXT.GUESS  SNG.NEXT.LLK  SNG.ONLY.POSTERIOR  \
# BARCODE
# AAACAGCCAAACAACA-1               1      -3972.79                 1.0
# AAACAGCCAAACATAG-1               1      -4850.10                 1.0
# AAACAGCCAAACCCTA-1               1      -3246.85                 1.0
# AAACAGCCAAACCTAT-1               1       -858.55                 1.0
# AAACAGCCAAACCTTG-1               1      -8448.12                 1.0
# ...                            ...           ...                 ...
# AACAAGCCACTGACTA-1               1      -2406.47                 1.0
# AACAAGCCACTGGCCA-1               3      -3161.07                 1.0
# AACAAGCCACTGGCTG-1               1      -7082.42                 1.0
# AACAAGCCACTTAACG-1               3      -2378.68                 1.0
# AACAAGCCACTTACAG-1               1      -5438.35                 1.0
#
#                    DBL.BEST.GUESS  DBL.BEST.LLK  DIFF.LLK.SNG.DBL
# BARCODE
# AAACAGCCAAACAACA-1            1,0      -3658.18             48.02
# AAACAGCCAAACATAG-1            4,0      -4497.91             84.71
# AAACAGCCAAACCCTA-1            1,0      -3040.60             31.90
# AAACAGCCAAACCTAT-1            1,0       -804.85              7.59
# AAACAGCCAAACCTTG-1            2,0      -7759.56            152.82
# ...                           ...           ...               ...
# AACAAGCCACTGACTA-1            3,0      -2246.44             25.06
# AACAAGCCACTGGCCA-1            3,0      -2934.66             34.93
# AACAAGCCACTGGCTG-1            1,0      -6605.68             67.89
# AACAAGCCACTTAACG-1            3,0      -2185.15             44.81
# AACAAGCCACTTACAG-1            2,0      -5024.36             77.05
#
# [8999 rows x 19 columns]

# %%
projdir = f'{basedir}/ambient/ambisim/cov_mux_test/'
s = samples[0]
mod = 'atac'
method = 'freemuxlet'

exp = '16_20'

indir = f'{projdir}/{exp}/demux/merged/{mod}/{s}'
demux = pd.read_csv(f'{indir}/{method}.csv', sep='\t', header=0, index_col=0).sort_index()

# %%
demux['donor_id'].value_counts()
# Out:
# 0.0    8999
# Name: donor_id, dtype: int64

# %%
projdir = f'{basedir}/ambient/ambisim/cov_doub_test/'
s = samples[0]
mod = 'atac'
method = 'demuxlet'
exp = '10_30'

indir = f'{projdir}/{exp}/demux/merged/{mod}/{s}'
demux = pd.read_csv(f'{indir}/{method}.csv', sep='\t', header=0, index_col=0).sort_index()

# %%
projdir = f'{basedir}/ambient/ambisim/cov_doub_test/'
s = samples[0]
mod = 'atac'
method = 'scsplit'
exp = '10_30'

indir = f'{projdir}/{exp}/demux/merged/{mod}/{s}'
demux = pd.read_csv(f'{indir}/{method}.csv', sep='\t', header=0, index_col=0).sort_index()

# %%
demux['donor_id'].value_counts()
# Out:
# 2          2208
# 4          2163
# 3          2082
# 0          1587
# doublet     959
# Name: donor_id, dtype: int64

# %%
projdir = f'{basedir}/ambient/ambisim/cov_doub_test/'
s = samples[0]
mod = 'gex'
method = 'scsplit'
exp = '10_20'

indir = f'{projdir}/{exp}/demux/merged/{mod}/{s}'
demux = pd.read_csv(f'{indir}/{method}.csv', sep='\t', header=0, index_col=0).sort_index()
demux['donor_id'].value_counts()
# Out:
# 0          2161
# 3          2107
# 2          2028
# 4          1785
# doublet     918
# Name: donor_id, dtype: int64
