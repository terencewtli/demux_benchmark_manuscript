# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
projdir = '/u/project/cluo/terencew/igvf/pilot/multiome/'
donors = list(np.loadtxt(f'{projdir}/txt/donors.txt', dtype=str))
samples = list(np.loadtxt(f'{projdir}/txt/samples.txt', dtype=str))
samples = samples[:2]
s = samples[0]
gex_methods = ['demuxlet', 'freemuxlet', 'vireo', 'vireo_nogenos',
               'scsplit', 'scsplit_nogenos', 'souporcell',
               'souporcell_nogenos', 'demuxalot']
atac_methods = ['demuxlet', 'freemuxlet', 'vireo', 'vireo_nogenos', 
            'scsplit', 'scsplit_nogenos', 'souporcell',
       'souporcell_nogenos', 'scavengers']

overlap_methods = ['demuxlet', 'freemuxlet', 'vireo', 'vireo_nogenos', 'scsplit', 'scsplit_nogenos',
                   'souporcell', 'souporcell_nogenos']

# %%
igvf_gex = pd.read_csv(f'{projdir}/csv/final_figures/figure4/igvf_overlap_gex.csv',
                       sep='\t', header=0, index_col=0)
igvf_atac = pd.read_csv(f'{projdir}/csv/final_figures/figure4/igvf_overlap_atac.csv',
                       sep='\t', header=0, index_col=0)

# %%
tmp_gex = np.triu(igvf_gex)
tmp_atac = np.tril(igvf_atac)
np.fill_diagonal(tmp_gex, val=np.zeros(len(gex_methods)))
igvf_merged = pd.DataFrame(tmp_gex + tmp_atac)
igvf_merged.columns = gex_methods
igvf_merged.index = atac_methods

# %%
igvf_merged.to_csv(f'{projdir}/csv/final_figures/figure4/igvf_overlap_merged.csv', sep='\t', header=True, index=True)

# %%
sns.diverging_palette(230, 20, as_cmap=True)

# %%
# igvf_merged.to_csv(f'{projdir}/csv/final)

# %%
fig, axes = plt.subplots(1, figsize=(10, 10))  # 2 rows, 4 columns

cmap = sns.diverging_palette(230, 20, as_cmap=True)
ax = sns.heatmap(igvf_merged, annot=True, xticklabels='auto', vmin=0.5, vmax=1, cmap=cmap)
cbar = ax.collections[0].colorbar
cbar.ax.tick_params(labelsize=25)

# %%
fig, axes = plt.subplots(1, figsize=(10, 10))  # 2 rows, 4 columns
font_size = 26

cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(igvf_merged, annot=True, xticklabels='auto', vmin=0.5, vmax=1, cmap=cmap,
            annot_kws={'size': 22}, cbar=False)
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)

# %% [markdown]
# ### adelus

# %%
adelus_gex = pd.read_csv(f'{projdir}/csv/final_figures/figure4/adelus_overlap_gex.csv',
                       sep='\t', header=0, index_col=0)
adelus_atac = pd.read_csv(f'{projdir}/csv/final_figures/figure4/adelus_overlap_atac.csv',
                       sep='\t', header=0, index_col=0)

# %%
tmp_gex = np.triu(adelus_gex)
tmp_atac = np.tril(adelus_atac)
np.fill_diagonal(tmp_gex, val=np.zeros(len(gex_methods)))
adelus_merged = pd.DataFrame(tmp_gex + tmp_atac)
adelus_merged.columns = gex_methods
adelus_merged.index = atac_methods

# %%
fig, axes = plt.subplots(1, figsize=(10, 10))  # 2 rows, 4 columns
font_size = 26

cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(adelus_merged, annot=True, xticklabels='auto', vmin=0.5, vmax=1, cmap=cmap,
            annot_kws={'size': 22}, cbar=False)
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5]),
#  [Text(0, 0.5, 'demuxlet'),
#   Text(0, 1.5, 'freemuxlet'),
#   Text(0, 2.5, 'vireo'),
#   Text(0, 3.5, 'vireo_nogenos'),
#   Text(0, 4.5, 'scsplit'),
#   Text(0, 5.5, 'scsplit_nogenos'),
#   Text(0, 6.5, 'souporcell'),
#   Text(0, 7.5, 'souporcell_nogenos'),
#   Text(0, 8.5, 'scavengers')])

# %%
adelus_merged.to_csv(f'{projdir}/csv/final_figures/figure4/adelus_overlap_merged.csv', sep='\t', header=True, index=True)
